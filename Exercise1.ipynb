# %% [markdown]
# Q6 is left

# %%
import numpy as np
import pandas as pd

# %%
salary=pd.read_csv('Salaries.csv')
salary
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13964\1925110741.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   salary=pd.read_csv('Salaries.csv')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %% [markdown]
# Q1- Show the first five rows of the dataset.

# %%
salary.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %% [markdown]
# Q2- Calculate the average of BasePay series.

# %%
#salary=salary.replace('Not Provided',0.0)

salary=salary.replace('Not Provided',np.nan)
salary=salary.replace('Not provided',np.nan)
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
# salary=salary.drop(columns=["Status","Benefits","Status","Notes"])
# salary
salary['BasePay'].dropna()
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
salary['BasePay']=salary['BasePay'].astype('float')

# %%
avg_BasePay=salary['BasePay'].mean()
avg_BasePay
# Out:
# 66325.4488404877

# %% [markdown]
# Q3- What is the highest amount of OvertimePay and OtherPay

# %%
salary['OvertimePay']=salary['OvertimePay'].astype('float') 
salary['OtherPay']=salary['OtherPay'].astype('float')

# %%
max_Overtime=salary['OvertimePay'].max()
max_Overtime
# Out:
# 245131.88

# %%
max_Overtime=salary['OtherPay'].max()
max_Overtime
# Out:
# 400184.25

# %% [markdown]
# Q4- What is the name of lowest paid person including Benefits.

# %%
# salary['TotalPay']=salary['TotalPay'].astype('float')
# min_TotalPay=salary['TotalPay'].min()
# min_TotalPay
#or
salary=salary.loc[salary['TotalPay'].idxmin()]
salary[['EmployeeName','TotalPayBenefits']]
# Out:
# EmployeeName        Joe Lopez
# TotalPayBenefits      -618.13
# Name: 148653, dtype: object

# %%
#or
salary[salary['TotalPay']==salary['TotalPay'].min()][['EmployeeName','TotalPayBenefits']]
# Out:
#        EmployeeName  TotalPayBenefits
# 148653    Joe Lopez           -618.13

# %% [markdown]
# Q5- What is the average BasePay of all employee per year(2011-2014)

# %%
a=salary.describe()
a
# Out:
#                   Id        BasePay       TotalPay  TotalPayBenefits  \
# count  148654.000000  148045.000000  148654.000000     148654.000000
# mean    74327.500000   66325.448840   74768.321972      93692.554811
# std     42912.857795   42764.635495   50517.005274      62793.533483
# min         1.000000    -166.010000    -618.130000       -618.130000
# 25%     37164.250000   33588.200000   36168.995000      44065.650000
# 50%     74327.500000   65007.450000   71426.610000      92404.090000
# 75%    111490.750000   94691.050000  105839.135000     132876.450000
# max    148654.000000  319275.010000  567595.430000     567595.430000
#
#                 Year  Notes
# count  148654.000000    0.0
# mean     2012.522643    NaN
# std         1.117538    NaN
# min      2011.000000    NaN
# 25%      2012.000000    NaN
# 50%      2013.000000    NaN
# 75%      2014.000000    NaN
# max      2014.000000    NaN

# %%
salary[['BasePay','Year']].groupby(by='Year').mean()
#or
#salary.groupby(by='Year').mean()['BasePay']
# Out:
#            BasePay
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %% [markdown]
# Q6- How many people have Chief word in their JobTitle (optional)

# %%
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
sum(salary['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 sum(salary['JobTitle'].apply(lambda x: chief_string(x)))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# ...

# %% [markdown]
# Q7- What are top 5 most common jobs?

# %%
top5_jobs=salary['JobTitle'].value_counts()
top5_jobs.head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# Q8- How many unique job titles are there?

# %%
salary['JobTitle'].nunique()
# Out:
# 2158

# %%
salary['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %% [markdown]
# Q9- Show last five rows of the dataset?

# %%
salary.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      0.0
# 148651  148652   Not provided                Not provided      0.0
# 148652  148653   Not provided                Not provided      0.0
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00     0.00      0.00              0.00  2014
# 148650          0.0      0.00      0.0      0.00              0.00  2014
# 148651          0.0      0.00      0.0      0.00              0.00  2014
# 148652          0.0      0.00      0.0      0.00              0.00  2014
# 148653          0.0   -618.13     0.00   -618.13           -618.13  2014
#
#         Notes         Agency Status
# 148649    NaN  San Francisco     PT
# 148650    NaN  San Francisco    NaN
# ...

# %% [markdown]
# Q10- How many job titles were represented by only one person in 2013? (example : JobTitles with only one occurence in 2013) (optional)

# %%
# salary['JobTitle'].value_counts(1)
sum(salary[salary['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %% [markdown]
# Q- What is the job title of Joseph Driscoll?

# %%
salary[salary['EmployeeName']=='Joseph Driscoll']['JobTitle']
# Out:
# 36198    Captain, Fire Suppression
# Name: JobTitle, dtype: object
