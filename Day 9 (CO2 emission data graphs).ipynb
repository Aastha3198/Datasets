# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('CO2_emission.csv')
data.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2011      2012      2013      2014  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
data.dropna()
# Out:
#              Country Name country_code                      Region  \
# 1             Afghanistan          AFG                  South Asia
# 2                  Angola          AGO          Sub-Saharan Africa
# 3                 Albania          ALB       Europe & Central Asia
# 4                 Andorra          AND       Europe & Central Asia
# 5    United Arab Emirates          ARE  Middle East & North Africa
# ..                    ...          ...                         ...
# 210                 Samoa          WSM         East Asia & Pacific
# 211           Yemen, Rep.          YEM  Middle East & North Africa
# 212          South Africa          ZAF          Sub-Saharan Africa
# 213                Zambia          ZMB          Sub-Saharan Africa
# 214              Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name       1990       1991       1992  \
# 1    CO2 emissions (metric tons per capita)   0.191745   0.167682   0.095958
# ...

# %%
data1=data.groupby(by=data['Region']).mean()
data1
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15092\1790496176.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1=data.groupby(by=data['Region']).mean()
#                                  1990       1991       1992       1993  \
# Region
# East Asia & Pacific          3.783577   3.838549   3.920955   3.958693
# Europe & Central Asia        8.531603   8.216745   7.633785   7.221487
# Latin America & Caribbean    2.238302   2.270151   2.495262   2.312084
# Middle East & North Africa   7.585239   7.382611   7.567304   8.040736
# North America               17.278118  16.872209  17.025547  16.965860
# South Asia                   0.329522   0.340487   0.379727   0.369016
# Sub-Saharan Africa           0.589543   0.603945   0.634070   0.631693
#
# ...

# %%
# a=data1.mean(axis=1)
# a

# %%
data1['max CO2 emission']=data1.max(axis=1)
data1
# Out:
#                                  1990       1991       1992       1993  \
# Region
# East Asia & Pacific          3.783577   3.838549   3.920955   3.958693
# Europe & Central Asia        8.531603   8.216745   7.633785   7.221487
# Latin America & Caribbean    2.238302   2.270151   2.495262   2.312084
# Middle East & North Africa   7.585239   7.382611   7.567304   8.040736
# North America               17.278118  16.872209  17.025547  16.965860
# South Asia                   0.329522   0.340487   0.379727   0.369016
# Sub-Saharan Africa           0.589543   0.603945   0.634070   0.631693
#
#                                  1994       1995       1996       1997  \
# Region
# East Asia & Pacific          3.992559   4.057945   4.049509   4.096781
# Europe & Central Asia        6.903652   6.709552   6.867240   6.717724
# Latin America & Caribbean    2.310858   2.386697   2.411546   2.504832
# Middle East & North Africa   8.410729   9.250754   9.415652   9.815083
# ...

# %%
plt.figure(figsize=(20,7))       # this shows the maximum emission of the mean of the emission of CO2 regionwise
plt.bar(data1.index,data1['max CO2 emission'])
plt.grid(alpha=0.2)
plt.title('Max CO2 emission regionwise',size=26)
plt.xlabel('Regions',size=16)
plt.ylabel('CO2 emission',size=16)
plt.show()

# %% [markdown]
# Graph 2

# %%
data_region=data['Region'].value_counts()
data_region
# Out:
# Europe & Central Asia         56
# Sub-Saharan Africa            48
# Latin America & Caribbean     42
# East Asia & Pacific           37
# Middle East & North Africa    21
# South Asia                     8
# North America                  3
# Name: Region, dtype: int64

# %%
s=[0,0,0,0,0,0,0.2]                       # Percentage of the country names falling in a particular region
plt.figure(figsize=(14,4))
plt.pie(data_region,autopct='%0.2f%%',labels=data_region.index,explode=s)
plt.title('Region vs Country Name count in that region',size=18)
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.hist(data['Region'])
plt.show()

# %% [markdown]
# Graph 3-

# %%
plt.bar(data['Country Name'][0:6],data['country_code'][0:6])
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# Graph 4-

# %%
plt.figure(figsize=(20,4))                  # Graph showing the CO2 emission in each year corresponding to the country name
plt.scatter(data['Country Name'][1:10],data['1990'][1:10],label='1990')
plt.scatter(data['Country Name'][1:10],data['1991'][1:10],label='1991')
plt.scatter(data['Country Name'][1:10],data['1992'][1:10],label='1992')
plt.plot(data['Country Name'][1:10],data['2019.1'][1:10],marker='*',markersize=10,label='2019.1')
plt.title('CO2 emission in each country',size=24)
plt.xlabel('COO2 emission',size=16)
plt.ylabel('Countries',size=16)
plt.grid(alpha=0.3)
plt.legend(shadow=1)
plt.show()

# %% [markdown]
# Using seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
CO2_emission=pd.read_csv('CO2_emission.csv')
CO2_emission.head(2)
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
#
#        1993      1994      1995  ...      2011      2012      2013      2014  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1  0.084721  0.075546  0.068468  ...  0.296506  0.259295  0.185624  0.146236
#
#        2015      2016      2017      2018      2019    2019.1
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1  0.172897  0.149789  0.131695  0.163295  0.159824  0.159824
#
# [2 rows x 35 columns]

# %%
data1=data.groupby(by=data['Region']).mean()
data1['max CO2 emission']=data1.max(axis=1)
data1
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15092\3705592164.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1=data.groupby(by=data['Region']).mean()
#                                  1990       1991       1992       1993  \
# Region
# East Asia & Pacific          3.783577   3.838549   3.920955   3.958693
# Europe & Central Asia        8.531603   8.216745   7.633785   7.221487
# Latin America & Caribbean    2.238302   2.270151   2.495262   2.312084
# Middle East & North Africa   7.585239   7.382611   7.567304   8.040736
# North America               17.278118  16.872209  17.025547  16.965860
# South Asia                   0.329522   0.340487   0.379727   0.369016
# Sub-Saharan Africa           0.589543   0.603945   0.634070   0.631693
#
# ...

# %%
w=0.8
a=np.arange(len(CO2_emission['Country Name'][0:10]))
xaxis=a+w

# %%
plt.figure(figsize=(15,7))      # this shows the maximum emission of the mean of the emission of CO2 regionwise
sns.barplot(data=CO2_emission[0:10],x='Country Name',y='1990',hue='Region',width=w)
plt.grid(alpha=0.2)
plt.title('CO2 emission in 1990',size=26)
plt.xticks(xaxis-w,CO2_emission['Country Name'][0:10])
plt.xlabel('Country Names',size=16)
plt.ylabel('CO2 emission in 1990',size=16)
# Out:
# Text(0, 0.5, 'CO2 emission in 1990')

# %%
plt.figure(figsize=(15,7))      # this shows the maximum emission of the mean of the emission of CO2 regionwise
sns.barplot(data=CO2_emission[0:10],x='Country Name',y='1990',hue='Region')
plt.grid(alpha=0.2)
plt.title('CO2 emission in 1990',size=26)
plt.xlabel('Country Names',size=16)
plt.ylabel('CO2 emission in 1990',size=16)
# Out:
# Text(0, 0.5, 'CO2 emission in 1990')

# %%
sns.pairplot(CO2_emission)

# %%
sns.scatterplot(data=CO2_emission,x='Country Name',y='1990',color='red')
# Out:
# <Axes: xlabel='Country Name', ylabel='1990'>
